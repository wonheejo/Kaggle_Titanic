# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
trainSS = train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
trainPS = train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
trainAS = train[['Age', 'Survived']].groupby(['Age']).mean().sort_values(by='Survived', ascending=False)

# %%
fig = plt.figure(figsize=(18,6))

plt.subplot2grid((2,3), (0,0))
varx = 'Sex'
vary = 'Survived'
data = trainSS
sns.barplot(varx, vary, data=data)
plt.title('Sex vs Survived')

plt.subplot2grid((2,3), (0,1))
varx = 'Pclass'
vary = 'Survived'
data = trainPS
sns.barplot(varx, vary, data=data)
plt.title('Pclass vs Survived')
# Out:
# Text(0.5, 1.0, 'Pclass vs Survived')

# %%
for cols in train.columns.tolist():
    if train[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, train[cols].isnull().sum(), train.shape[0]))
# Out:
# Missing Age: 177/891
# Missing Cabin: 687/891
# Missing Embarked: 2/891

# %%
for cols in test.columns.tolist():
    if test[cols].isnull().sum():
        print('Missing  {}: {}/{}' .format(cols, test[cols].isnull().sum(), train.shape[0]))
# Out:
# Missing  Age: 86/891
# Missing  Fare: 1/891
# Missing  Cabin: 327/891

# %%
train['Embarked'] = train['Embarked'].fillna('S')

# %%
for cols in train.columns.tolist():
    if train[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, train[cols].isnull().sum(), train.shape[0]))
# Out:
# Missing Age: 177/891
# Missing Cabin: 687/891

# %%
for cols in test.columns.tolist():
    if test[cols].isnull().sum():
        print('Missing  {}: {}/{}' .format(cols, test[cols].isnull().sum(), train.shape[0]))
# Out:
# Missing  Age: 86/891
# Missing  Fare: 1/891
# Missing  Cabin: 327/891

# %%
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
train = train.drop(['Cabin', 'Ticket'], axis=1)

# %%
test = test.drop(['Cabin', 'Ticket'], axis=1)

# %%
for cols in test.columns.tolist():
    if test[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, test[cols].isnull().sum(), test.shape[0]))
# Out:
# Missing Age: 86/418
# Missing Fare: 1/418

# %%
for cols in train.columns.tolist():
    if train[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, train[cols].isnull().sum(), train.shape[0]))
# Out:
# Missing Age: 177/891

# %%
def bar_chart(feature):
    survived = train[train['Survived'] == 1][feature].value_counts()
    dead = train[train['Survived'] == 0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar', stacked=True, figsize=(12, 6))

# %%
bar_chart('Sex')

# %%
bar_chart('Embarked')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
trainAP = train[['Age', 'Pclass']].groupby(['Pclass'], as_index = False).mean().sort_values(by='Pclass', ascending=False)

# %%
trainAP
# Out:
#    Pclass        Age
# 2       3  25.140620
# 1       2  29.877630
# 0       1  38.233441

# %%
fig = plt.figure(figsize=(16, 8))
plt.subplot2grid((1, 2), (0, 0))
sns.barplot(data = train, x='Pclass', y='Age', hue='Sex')
plt.title('Sex vs Pclass/Age Train Set')

plt.subplot2grid((1, 2), (0, 1))
sns.barplot(data = test, x='Pclass', y='Age', hue='Sex')
plt.title('Sex vs Pclass/Age Test Set')

plt.show()

# %%
age_male_train = round(train[(train['Sex']=='male')]['Age'].groupby(train['Pclass']).mean(), 2)
age_female_train = round(train[(train['Sex']=='female')]['Age'].groupby(train['Pclass']).mean(), 2)

age_male_test = round(test[(test['Sex']=='male')]['Age'].groupby(test['Pclass']).mean(), 2)
age_female_test = round(test[(test['Sex']=='female')]['Age'].groupby(test['Pclass']).mean(), 2)

total = pd.concat([age_male_train, age_female_train, age_male_test, age_female_test], axis=1, keys=['Male Train', 'Female Train', 'Male Test', 'Female Test'])
total
# Out:
#         Male Train  Female Train  Male Test  Female Test
# Pclass
# 1            41.28         34.61      40.52        41.33
# 2            30.74         28.72      30.94        24.38
# 3            26.51         21.75      24.53        23.07

# %%
def age_fillna_train(APStrn):
    Age = APStrn[0]
    Pclass = APStrn[1]
    Sex = APStrn[2]
    
    if pd.isnull(Age):
        if Sex == 'male':
            if Pclass == 1:
                return 41.28
            if Pclass == 2:
                return 30.74
            if Pclass == 3:
                return 26.51
            
        if Sex == 'female':
            if Pclass == 1:
                return 34.61
            if Pclass == 2:
                return 28.72
            if Pclass == 3:
                return 21.75
        
    else:
        return Age
    
def age_fillna_test(APStst):
    Age = APStst[0]
    Pclass = APStst[1]
    Sex = APStst[2]
    
    if pd.isnull(Age):
        if Sex == 'male':
            if Pclass == 1:
                return 40.52
            if Pclass == 2:
                return 30.94
            if Pclass == 3:
                return 24.53
        if Sex == 'female':
            if Pclass == 1:
                return 41.33
            if Pclass == 2:
                return 24.38
            if Pclass == 3:
                return 23.07
    else:
        return Age

# %%
train['Age'] = train[['Age', 'Pclass', 'Sex']].apply(age_fillna_train, axis=1)
test['Age'] = test[['Age', 'Pclass', 'Sex']].apply(age_fillna_train, axis=1)

# %%
for cols in train.columns.tolist():
    if train[cols].isnull().sum():
        print('Missing {} : {}/{}' .format(cols, train[cols].isnull().sum(), train.shape[0]))

# %%
for cols in test.columns.tolist():
    if test[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, test[cols].isnull().sum(), test.shape[0]))
# Out:
# Missing Fare: 1/418

# %%
test['Fare'].fillna(test.groupby('Pclass')['Fare'].transform('median'), inplace=True)

# %%
for cols in test.columns.tolist():
    if test[cols].isnull().sum():
        print('Missing {}: {}/{}' .format(cols, test[cols].isnull().sum(), test.shape[0]))

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# ...

# %%
train_test_set = [train, test]

for dataset in train_test_set:
    dataset.loc[dataset['Sex'] == 'male', 'Sex'] = 0
    dataset.loc[dataset['Sex'] == 'female', 'Sex'] = 1

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# 5          897       3                    Svensson, Mr. Johan Cervin    0
# 6          898       3                          Connolly, Miss. Kate    1
# 7          899       2                  Caldwell, Mr. Albert Francis    0
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1
# 9          901       3                       Davies, Mr. John Samuel    0
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# ...

# %%
for dataset in train_test_set:
    dataset.loc[dataset['Embarked'] == 'S', 'Embarked'] = 0
    dataset.loc[dataset['Embarked'] == 'C', 'Embarked'] = 1
    dataset.loc[dataset['Embarked'] == 'Q', 'Embarked'] = 2

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex    Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    0  22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.00      1
# 2                             Heikkinen, Miss. Laina    1  26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.00      1
# 4                           Allen, Mr. William Henry    0  35.00      0
# 5                                   Moran, Mr. James    0  26.51      0
# 6                            McCarthy, Mr. Timothy J    0  54.00      0
# ...

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# 5          897       3                    Svensson, Mr. Johan Cervin    0
# 6          898       3                          Connolly, Miss. Kate    1
# 7          899       2                  Caldwell, Mr. Albert Francis    0
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1
# 9          901       3                       Davies, Mr. John Samuel    0
#
#     Age  SibSp  Parch     Fare  Embarked
# 0  34.5      0      0   7.8292         2
# 1  47.0      1      0   7.0000         0
# ...

# %%
train['AgeBand'] = pd.cut(train['Age'], 6)
train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#             AgeBand  Survived
# 0    (0.34, 13.683]  0.591549
# 2   (26.947, 40.21]  0.445283
# 3   (40.21, 53.473]  0.363636
# 4  (53.473, 66.737]  0.348837
# 1  (13.683, 26.947]  0.317708
# 5    (66.737, 80.0]  0.142857

# %%
for dataset in train_test_set:
    dataset.loc[dataset['Age'] <= 14, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 14) & (dataset['Age'] <= 27), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 27) & (dataset['Age'] <= 40), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 40) & (dataset['Age'] <= 53), 'Age'] = 3
    dataset.loc[(dataset['Age'] > 53) & (dataset['Age'] <= 67), 'Age'] = 4
    dataset.loc[dataset['Age'] > 67, 'Age'] = 5

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  1.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  2.0      1      0
# 2                             Heikkinen, Miss. Laina    1  1.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  2.0      1      0
# 4                           Allen, Mr. William Henry    0  2.0      0      0
#
#       Fare  Embarked           AgeBand
# 0   7.2500         0  (13.683, 26.947]
# 1  71.2833         1   (26.947, 40.21]
# 2   7.9250         0  (13.683, 26.947]
# 3  53.1000         0   (26.947, 40.21]
# 4   8.0500         0   (26.947, 40.21]

# %%
train = train.drop(['AgeBand'], axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  1.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  2.0      1      0
# 2                             Heikkinen, Miss. Laina    1  1.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  2.0      1      0
# 4                           Allen, Mr. William Henry    0  2.0      0      0
#
#       Fare  Embarked
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         0
# 3  53.1000         0
# 4   8.0500         0

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#    Age  SibSp  Parch     Fare  Embarked
# 0  2.0      0      0   7.8292         2
# 1  3.0      1      0   7.0000         0
# 2  4.0      0      0   9.6875         2
# 3  1.0      0      0   8.6625         0
# 4  1.0      1      1  12.2875         0

# %%
train['Name'].value_counts()
# Out:
# Gale, Mr. Shadrach                              1
# Gustafsson, Mr. Johan Birger                    1
# Roebling, Mr. Washington Augustus II            1
# Skoog, Mr. Wilhelm                              1
# Danoff, Mr. Yoto                                1
#                                                ..
# Greenberg, Mr. Samuel                           1
# Doharr, Mr. Tannous                             1
# Bateman, Rev. Robert James                      1
# Jerwan, Mrs. Amin S (Marie Marthe Thuillard)    1
# McCoy, Miss. Agnes                              1
# Name: Name, Length: 891, dtype: int64

# %%
train['Title'] = train['Name']

# %%
train['Title'] = train['Title'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Major         2
# Mlle          2
# Jonkheer      1
# Don           1
# Countess      1
# Ms            1
# Mme           1
# Sir           1
# Lady          1
# Capt          1
# Name: Title, dtype: int64

# %%
titlemap = {'Mr': 0, 'Miss': 1, 'Mrs': 2, 'Master': 3, 'Dr': 4, 'Rev': 4, 'Col': 4, 'Major': 4, 'Mlle': 4, 'Jonkheer': 4, 'Don': 4, 'Countess': 3, 'Ms': 1, 'Mme': 2, 'Sir': 4, 'Lady': 4, 'Capt': 4}
train['Title'] = train['Title'].map(titlemap)

# %%
train['Title'].value_counts()
# Out:
# 0    517
# 1    183
# 2    126
# 3     41
# 4     24
# Name: Title, dtype: int64

# %%
train = train.drop(['Name'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-9cd394602e24> in <module>
# ----> 1 train = train.drop(['Name'], axis=1)
#       2 train.head(10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    0  1.0      1      0   7.2500         0
# 1            2         1       1    1  2.0      1      0  71.2833         1
# 2            3         1       3    1  1.0      0      0   7.9250         0
# 3            4         1       1    1  2.0      1      0  53.1000         0
# 4            5         0       3    0  2.0      0      0   8.0500         0
# 5            6         0       3    0  1.0      0      0   8.4583         2
# 6            7         0       1    0  4.0      0      0  51.8625         0
# 7            8         0       3    0  0.0      3      1  21.0750         0
# 8            9         1       3    1  1.0      0      2  11.1333         0
# 9           10         1       2    1  0.0      1      0  30.0708         1
#
#    Title
# 0      0
# 1      2
# 2      1
# 3      2
# 4      0
# 5      0
# 6      0
# 7      3
# 8      2
# 9      2

# %%
test['Title'] = test['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: Title, dtype: int64

# %%
titlemap = {'Mr': 0, 'Miss': 1, 'Mrs':2, 'Master': 3, 'Col': 4, 'Rev': 4, 'Ms': 1, 'Dr': 4, 'Dona': 4}
test['Title'] = test['Title'].map(titlemap)

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# 5          897       3                    Svensson, Mr. Johan Cervin    0
# 6          898       3                          Connolly, Miss. Kate    1
# 7          899       2                  Caldwell, Mr. Albert Francis    0
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1
# 9          901       3                       Davies, Mr. John Samuel    0
#
#    Age  SibSp  Parch     Fare  Embarked  Title
# 0  2.0      0      0   7.8292         2      0
# 1  3.0      1      0   7.0000         0      2
# ...

# %%
test = test.drop(['Name'], axis = 1)
